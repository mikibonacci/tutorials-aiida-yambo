# %% [markdown]
# # Automated DFT band interpolation via Wannierization
#
# In this example we show how to obtain the DFT interpolated bands by means of the `aiida-wannier90` plugin.

# %%
from aiida import orm, load_profile
load_profile()
# Out:
# Profile<uuid='3745313b017b418697d37cbf16c4e7ef' name='generic'>

# %%
from aiida_wannier90_workflows.utils.workflows.builder.serializer import print_builder 
from aiida_wannier90_workflows.utils.kpoints import get_explicit_kpoints_from_mesh
from aiida_wannier90_workflows.utils.workflows.builder.setter import set_parallelization, set_num_bands, set_kpoints
from aiida_wannier90_workflows.utils.workflows.builder.submit import submit_and_add_group 
from aiida_wannier90_workflows.common.types import WannierProjectionType
from aiida_wannier90_workflows.workflows import Wannier90BandsWorkChain

# %% [markdown]
# ## minimal inputs needed for protocols

# %%
import yaml,io

# Read YAML file
with open("../configuration/codes_localhost_yw90.yaml", 'r') as stream:
    codes = yaml.safe_load(stream)
    
with open("../configuration/resources_localhost.yaml", 'r') as stream:
    resources = yaml.safe_load(stream)

# %%
from aiida.orm import QueryBuilder
qb = QueryBuilder()
qb.append(orm.Group, filters={'label': 'Silicon/bulk'}, tag='group')
qb.append(orm.StructureData, with_group='group')

loaded_structure_id = qb.all()[0][0].pk

# %%
options = {
    'pseudo_family':"PseudoDojo/0.4/PBE/SR/standard/upf",
    'protocol':'fast',
    #'parent_id':274, #not necessary to set; if you want it, take ytheour previously nscf id (pk) to skip the DFT part.
    'structure_id':loaded_structure_id,
}

# %%
projections="analytic"

if projections=="analytic":
    wannier_projection_type=WannierProjectionType.ANALYTIC
else:
    WannierProjectionType.ATOMIC_PROJECTORS_QE

# %%
builder = Wannier90BandsWorkChain.get_builder_from_protocol(
        codes=codes,
        structure=orm.load_node(options["structure_id"]),
        pseudo_family=options["pseudo_family"],
        protocol="fast",
        projection_type=wannier_projection_type,
    )
# Out:
# Summary of key input parameters:
#   Formula: Si2
#   PseudoFamily: PseudoDojo/0.4/PBE/SR/standard/upf
#   ElectronicType: METAL
#   SpinType: NONE
#   WannierProjectionType: ANALYTIC
#   WannierDisentanglementType: SMV
#   WannierFrozenType: ENERGY_FIXED
#   num_bands: 12
#   num_wann: 8
#   mp_grid: [5, 5, 5]

# %%
parallelization = dict(
    max_wallclock_seconds=24 * 3600,
    # num_mpiprocs_per_machine=48,
    #npool=4,
    num_machines=1,
)

set_parallelization(
    builder,
    parallelization=parallelization,
    process_class=Wannier90BandsWorkChain,
)


#### START computational resources settings.

builder['nscf']['pw']['metadata']['options'] = resources

builder['scf']['pw']['metadata']['options'] = resources

builder['pw2wannier90']['pw2wannier90']['metadata']['options'] = resources

builder['wannier90']['wannier90']['metadata']['options'] = resources

#### END computational resources settings.

# %%
# Use 4x4x4 kmesh
kpoints = get_explicit_kpoints_from_mesh(builder.structure, [8,8,8])
set_kpoints(builder, kpoints, process_class=Wannier90BandsWorkChain)

# %%
# START projections settings:
    
set_num_bands(
    builder=builder, 
    num_bands=14,                   # KS states used in the Wannierization
    #exclude_bands=range(1,5), 
    process_class=Wannier90BandsWorkChain)

params = builder.wannier90.wannier90.parameters.get_dict()

## START explicit atomic projections:
if projections=="analytic":

    del builder.projwfc
    builder.wannier90.auto_energy_windows = False
    builder.wannier90.shift_energy_windows = True
    params['num_wann'] = 8
    builder.wannier90.wannier90.projections = orm.List(list=['Si:s','Si:p'])
    params.pop('auto_projections', None) # Uncomment this if you want analytic atomic projections

    #
    # The following line can be also deleted.
    builder['pw2wannier90']['pw2wannier90']['parameters'] = orm.Dict(dict={'inputpp': {'atom_proj': False}})

## END explicit atomic projections:

# optional settings.
#params.pop('dis_proj_min', None)
#params.pop('dis_proj_max', None)
#params['num_wann'] = 16
#params['dis_froz_max'] = 2

params = orm.Dict(dict=params)
builder.wannier90.wannier90.parameters = params

# END projections settings.

# %%
print_builder(builder)
# Out:
# {'clean_workdir': False,
#  'nscf': {'kpoints': '512 kpts<None>',
#           'kpoints_force_parity': False,
#           'pw': {'code': 'pw_develop@local_slurm<365>',
#                  'metadata': {'options': {'max_wallclock_seconds': 3600,
#                                           'prepend_text': 'export '
#                                                           'OMP_NUM_THREADS=1',
#                                           'resources': {'num_cores_per_mpiproc': 1,
#                                                         'num_machines': 1,
#                                                         'num_mpiprocs_per_machine': 1}}},
#                  'parallelization': {'npool': 1},
#                  'parameters': {'CONTROL': {'calculation': 'nscf',
#                                             'etot_conv_thr': 0.0002,
#                                             'forc_conv_thr': 0.001,
#                                             'restart_mode': 'from_scratch',
#                                             'tprnfor': True,
#                                             'tstress': True},
#                                 'ELECTRONS': {'conv_thr': 8e-10,
#                                               'diago_full_acc': True,
#                                               'electron_maxstep': 80,
#                                               'mixing_beta': 0.4,
#                                               'startingpot': 'file'},
#                                 'SYSTEM': {'degauss': 0.01,
#                                            'ecutrho': 144.0,
#                                            'ecutwfc': 36.0,
#                                            'nbnd': 14,
#                                            'noinv': True,
#                                            'nosym': True,
#                                            'occupations': 'smearing',
#                                            'smearing': 'cold'}},
#                  'pseudos': {'Si': 'Si.upf<331>'}}},
#  'pw2wannier90': {'pw2wannier90': {'code': 'pw2wannier90_develop@local_slurm<366>',
#                                    'metadata': {'options': {'max_wallclock_seconds': 3600,
#                                                             'prepend_text': 'export '
#                                                                             'OMP_NUM_THREADS=1',
#                                                             'resources': {'num_cores_per_mpiproc': 1,
#                                                                           'num_machines': 1,
#                                                                           'num_mpiprocs_per_machine': 1}}},
#                                    'parameters': {'inputpp': {'atom_proj': False}},
#                                    'settings': {'cmdline': ['-nk', '1']}}},
#  'scf': {'kpoints': '512 kpts<None>',
#          'kpoints_distance': 0.2,
#          'kpoints_force_parity': False,
#          'pw': {'code': 'pw_develop@local_slurm<365>',
#                 'metadata': {'options': {'max_wallclock_seconds': 3600,
#                                          'prepend_text': 'export '
#                                                          'OMP_NUM_THREADS=1',
#                                          'resources': {'num_cores_per_mpiproc': 1,
#                                                        'num_machines': 1,
#                                                        'num_mpiprocs_per_machine': 1}}},
#                 'parallelization': {'npool': 1},
#                 'parameters': {'CONTROL': {'calculation': 'scf',
#                                            'etot_conv_thr': 0.0002,
#                                            'forc_conv_thr': 0.001,
#                                            'tprnfor': True,
#                                            'tstress': True},
#                                'ELECTRONS': {'conv_thr': 8e-10,
#                                              'electron_maxstep': 80,
#                                              'mixing_beta': 0.4},
#                                'SYSTEM': {'degauss': 0.01,
#                                           'ecutrho': 144.0,
#                                           'ecutwfc': 36.0,
#                                           'nosym': False,
#                                           'occupations': 'smearing',
#                                           'smearing': 'cold'}},
#                 'pseudos': {'Si': 'Si.upf<331>'}}},
#  'structure': 'Si2<370>',
#  'wannier90': {'auto_energy_windows': False,
#                'auto_energy_windows_threshold': 0.9,
#                'shift_energy_windows': True,
#                'wannier90': {'code': 'wannier90@local_slurm<369>',
#                              'kpoints': '512 kpts<None>',
#                              'metadata': {'options': {'max_wallclock_seconds': 3600,
#                                                       'prepend_text': 'export '
#                                                                       'OMP_NUM_THREADS=1',
#                                                       'resources': {'num_cores_per_mpiproc': 1,
#                                                                     'num_machines': 1,
#                                                                     'num_mpiprocs_per_machine': 1}}},
#                              'parameters': {'bands_plot': True,
#                                             'conv_tol': 2e-05,
#                                             'conv_window': 1,
#                                             'dis_conv_tol': 2e-05,
#                                             'dis_froz_max': 2.0,
#                                             'dis_num_iter': 400,
#                                             'mp_grid': [8, 8, 8],
#                                             'num_bands': 14,
#                                             'num_cg_steps': 200,
#                                             'num_iter': 400,
#                                             'num_wann': 8},
#                              'projections': ['Si:s', 'Si:p'],
#                              'settings': {}}}}

# %% [markdown]
# ### Computational resources

# %%
from aiida.engine import submit

# %%
run = None

# %%
if run:
    print('run is already running -> {}'.format(run.pk))
    print('sure that you want to run again?, if so, copy the else instruction in the cell below and run!')
else:
    run = submit(builder)

print(run)
# Out:
# uuid: ff925476-f8b1-4157-bb28-ba692bdf5e1c (pk: 6645) (aiida.workflows:wannier90_workflows.bands)

# %%
# !verdi process report {run.pk}
# Out:
# 2024-02-19 11:55:36 [4020 | REPORT]: [6645|Wannier90BandsWorkChain|run_seekpath]: launching seekpath: Si2 -> Si2
# 2024-02-19 11:55:37 [4021 | REPORT]: [6645|Wannier90BandsWorkChain|run_scf]: launching PwBaseWorkChain<6653> in scf mode
# 2024-02-19 11:55:38 [4022 | REPORT]:   [6653|PwBaseWorkChain|run_process]: launching PwCalculation<6656> iteration #1
# 2024-02-19 11:56:30 [4023 | REPORT]:   [6653|PwBaseWorkChain|results]: work chain completed after 1 iterations
# 2024-02-19 11:56:30 [4024 | REPORT]:   [6653|PwBaseWorkChain|on_terminated]: remote folders will not be cleaned
# 2024-02-19 11:56:31 [4025 | REPORT]: [6645|Wannier90BandsWorkChain|run_nscf]: launching PwBaseWorkChain<6663> in nscf mode
# 2024-02-19 11:56:31 [4026 | REPORT]:   [6663|PwBaseWorkChain|run_process]: launching PwCalculation<6666> iteration #1
# 2024-02-19 11:58:13 [4027 | REPORT]:   [6663|PwBaseWorkChain|results]: work chain completed after 1 iterations
# 2024-02-19 11:58:13 [4028 | REPORT]:   [6663|PwBaseWorkChain|on_terminated]: remote folders will not be cleaned
# 2024-02-19 11:58:14 [4029 | REPORT]: [6645|Wannier90BandsWorkChain|run_wannier90_pp]: launching Wannier90BaseWorkChain<6675> in postproc mode
# 2024-02-19 11:58:15 [4030 | REPORT]:   [6675|Wannier90BaseWorkChain|run_process]: launching Wannier90Calculation<6677> iteration #1
# 2024-02-19 11:58:19 [4031 | REPORT]:   [6675|Wannier90BaseWorkChain|results]: work chain completed after 1 iterations
# 2024-02-19 11:58:19 [4032 | REPORT]:   [6675|Wannier90BaseWorkChain|on_terminated]: remote folders will not be cleaned
# 2024-02-19 11:58:20 [4033 | REPORT]: [6645|Wannier90BandsWorkChain|run_pw2wannier90]: launching Pw2wannier90BaseWorkChain<6683>
# 2024-02-19 11:58:20 [4034 | REPORT]:   [6683|Pw2wannier90BaseWorkChain|run_process]: launching Pw2wannier90Calculation<6684> iteration #1
# 2024-02-19 11:59:50 [4035 | REPORT]:   [6683|Pw2wannier90BaseWorkChain|results]: work chain completed after 1 iterations
# 2024-02-19 11:59:51 [4036 | REPORT]:   [6683|Pw2wannier90BaseWorkChain|on_terminated]: remote folders will not be cleaned
# 2024-02-19 11:59:52 [4037 | REPORT]: [6645|Wannier90BandsWorkChain|run_wannier90]: launching Wannier90BaseWorkChain<6693>
# 2024-02-19 11:59:53 [4038 | REPORT]:   [6693|Wannier90BaseWorkChain|run_process]: launching Wannier90Calculation<6695> iteration #1
# 2024-02-19 12:00:13 [4039 | REPORT]:   [6693|Wannier90BaseWorkChain|results]: work chain completed after 1 iterations
# 2024-02-19 12:00:14 [4040 | REPORT]:   [6693|Wannier90BaseWorkChain|on_terminated]: remote folders will not be cleaned
# 2024-02-19 12:00:14 [4041 | REPORT]: [6645|Wannier90BandsWorkChain|results]: Wannier90BandsWorkChain successfully completed
# 2024-02-19 12:00:15 [4042 | REPORT]: [6645|Wannier90BandsWorkChain|on_terminated]: remote folders will not be cleaned

# %% [markdown]
# ## Plotting results
#
# It is also possible to use the command line:
#
# ```bash
# aiida-wannier90-workflows plot band 6645 # the Wannier90BandsWorkChain pk
# ```

# %%
import matplotlib.pyplot as plt

#last occupied band index.
b = 4 

w90_qe = run.outputs.band_structure

# %%
# Just a way to have nice plotting.

l_x = []
l_names = []
l_remove = []

for i in w90_qe.labels:
    if len(l_x)>0:
        if i[0] == l_x[-1]+1:
            if i[1] == 'GAMMA':
                l_names[-1] = l_names[-1]+"|$\Gamma$"
            else:
                l_names[-1] = l_names[-1]+"|"+i[1]
            l_remove.append(i[0])
        else:    
            l_x.append(i[0])
            if i[1] == 'GAMMA':
                l_names.append("$\Gamma$")
            else:
                l_names.append(i[1])
    else:    
        l_x.append(i[0])
        
        if i[1] == 'GAMMA':
            l_names.append("$\Gamma$")
        else:
            l_names.append(i[1])

# %%
w90bands = w90_qe.get_bands()

# %%
import numpy as np
for j in l_remove:
    w90bands = np.delete(w90bands, obj=j, axis=0)

# %%
fig,ax=plt.subplots(figsize=[15,7])
plt.plot(w90bands-max(w90_qe.get_bands()[:,b-1]),'--',color='red')

plt.plot(w90bands[0,b-1]-max(w90_qe.get_bands()[:,b-1]),'--',color='red',label = 'W90')
plt.ylim(-10,10)

plt.grid()
plt.xticks(l_x,l_names)
plt.tick_params(axis='both',labelsize=20)
plt.xlim(0,max(l_x))
plt.ylabel("eV",fontsize=20)
#plt.ylim(-2,5)
plt.legend()

#plt.savefig('plot_.pdf')
