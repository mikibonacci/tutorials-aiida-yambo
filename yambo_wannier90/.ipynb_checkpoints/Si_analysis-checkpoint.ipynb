# %% [markdown]
# # Comparison between QE bands, W90@QE and W90@G0W0

# %%
from aiida import orm, load_profile
load_profile()
from aiida import orm
import matplotlib.pyplot as plt

# %%
gww90, b = orm.load_node(6530),4   # the YamboWannier90WorkChain node, and the occupied bands.

dft = gww90.outputs.band_structures.wannier90 #load_node(75931) ,76061
qp = gww90.outputs.band_structures.wannier90_qp #load_node(75946)   ,76076
bands_qe = orm.load_node(6704).outputs.output_band

# %%
# Just a way to have nice plotting.

l_x = []
l_names = []
l_remove = []

for i in bands_qe.labels:
    if len(l_x)>0:
        if i[0] == l_x[-1]+1:   #I do not want the same point to be doubled, e.g. for U|Gamma case.
            if i[1] == 'GAMMA':
                l_names[-1] = l_names[-1]+"|$\Gamma$"
            else:
                l_names[-1] = l_names[-1]+"|"+i[1]
            l_remove.append(i[0])
        else:    
            l_x.append(i[0])
            if i[1] == 'GAMMA':
                l_names.append("$\Gamma$")
            else:
                l_names.append(i[1])
    else:    
        l_x.append(i[0])
        
        if i[1] == 'GAMMA':
            l_names.append("$\Gamma$")
        else:
            l_names.append(i[1])
            
dft_bands=bands_qe.get_bands()
w90qe_bands=dft.get_bands()
w90GW_bands=qp.get_bands()

import numpy as np
for j in l_remove:
    w90GW_bands = np.delete(w90GW_bands, obj=j, axis=0)
    w90qe_bands = np.delete(w90qe_bands, obj=j, axis=0)
    dft_bands = np.delete(dft_bands, obj=j, axis=0)

# %%
fig,ax=plt.subplots(figsize=[15,7])
plt.plot(dft_bands-max(dft_bands[:,b-1]),'-',color='green') #,label = 'QE')
plt.plot(w90qe_bands-max(w90qe_bands[:,b-1]),'--',color='red',ms=2) #,label='W90@QE')
plt.plot(w90GW_bands[:,:]-max(w90GW_bands[::2,b-1]),'-',color='black',ms=2) #,label='W90@G0W0')

plt.plot(dft_bands[0,0]-max(dft_bands[:,b-1]),'-',color='green',label = 'QE')
plt.plot(w90qe_bands[0,0]-max(w90qe_bands[:,b-1]),'--',color='red',ms=2,label='W90@QE')
plt.plot(w90GW_bands[0,0]-max(w90GW_bands[::2,b-1]),'-',color='black',ms=2,label='W90@G0W0')

plt.grid()
plt.xticks(l_x,l_names)
plt.tick_params(axis='both',labelsize=20)
plt.xlim(0,max(l_x))
plt.ylabel("eV",fontsize=20)
plt.ylim(-10,10)
#plt.ylim(-2,5)
plt.legend(fontsize=20)

#plt.savefig('plot_.pdf')

# %%
fig,ax=plt.subplots(figsize=[7,5])
plt.plot(dft.get_bands(),qp.get_bands(),'o',color='black')
#plt.ylim(-3,3)
#plt.xlim(-3,3)
plt.grid()
plt.xlabel('DFT')
plt.ylabel('QP')
# Out:
# Text(0, 0.5, 'QP')
